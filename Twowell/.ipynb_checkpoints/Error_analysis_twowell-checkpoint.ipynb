# %%
# from google.colab import drive
# drive.mount('/content/drive')

import os
import copy

# os.chdir('/content/drive/MyDrive/Colab Notebooks/Shashank')

os.chdir('/Users/shashanksule/Documents/TMDmaps/Twowell')
# Regular Modules
import numpy as np
import sklearn as sklearn
import matplotlib.pyplot as plt
import datetime
import scipy.integrate as scint
#from numpy.random import default_rng
import numpy.ma as ma
import matplotlib.tri as tri
import scipy.io
import time 
from mpl_toolkits.mplot3d import axes3d
# parallelization modules 

from math import nan
from joblib import Parallel, delayed
import multiprocessing
import itertools

# # My Modules
import helpers as helpers
import model_systems as model_systems
import diffusion_map as dmap

# %% [markdown]
# # Potential

# %% [markdown]
# # Error Analysis

# %%
# Load error data
os.chdir(os.getcwd() + "/error_data")
err_metad_long_FEM_TMD = np.load("Error_datametadynamicsbeta_1_FEMpts_twowell.npy")
err_metad_long_TMD_FEM = np.load("Error_datametadynamicsbeta_1_TMDpts_twowell.npy")
err_FEM_TMD = np.load("Error_datagibbsbeta_1_FEMpts_twowell.npy")
err_TMD_FEM = np.load("Error_datagibbsbeta_1_TMDpts_twowell.npy")
err_unif_FEM_TMD = np.load("Error_datauniformbeta_1_FEMpts_twowell.npy")
err_unif_TMD_FEM = np.load("Error_datauniformbeta_1_TMDpts_twowell.npy")
k_metad = np.load("kernel_data_metadynamics.npy")
k_gibbs = np.load("kernel_data_gibbs.npy")
k_unif = np.load("kernel_data_uniform.npy")

eps_vals = 2.0**np.arange(-18, 4, 0.5)
delta_vals = np.linspace(1e-6, 1e-1, 10)[:4]
# knn_vals = 2**np.arange(10,6,-5)
# knn_vals = np.array([np.int64(N*0.1)])
vbdry_vals = np.arange(1, -50, -60)
num_idx = eps_vals.shape[0]
num_delta = delta_vals.shape[0]
# num_knn = knn_vals.shape[0]
num_vbdry = vbdry_vals.shape[0]

# %%
# plot dependence on delta net for gibbs data
colors_FEM = iter(plt.cm.jet(np.linspace(0,1,num_delta)))
fig, (ax2,ax3) = plt.subplots(1,2, figsize = (16,8))
ax2.set(xscale = "log")
for i in range(4):
  if i == 0:
    color = next(colors_FEM)
    ax2.plot(eps_vals[1:], err_FEM_TMD[1:, i,-1,-1], 
             # marker = 'o',
             color = color,
             label = "Gibbs Points")
    ax2.axvline(x = eps_vals[np.argmax(k_gibbs[1:,i,-1,-1])], linestyle = '--', color = color)
  else:
    color = next(colors_FEM)
    ax2.plot(eps_vals[1:], err_FEM_TMD[1:, i,-1,-1], 
             # marker = 'o',
             color = color,
             label = "Gibbs points at delta =" + str(delta_vals[i]))
    ax2.axvline(x = eps_vals[np.argmax(k_gibbs[1:,i,-1,-1])], linestyle = '--', color = color)
ax2.legend(bbox_to_anchor=(0.50, 0.15))
ax2.set(ylim = (0.0,0.06), title = "Errors on Gibbs Density", ylabel = "RMS Error", xlabel = "Kernel Bandwidth");

# plot dependence on delta net for metadynamics data
colors_FEM = iter(plt.cm.jet(np.linspace(0,1,num_delta)))
ax3.set(xscale = "log")
for i in range(4):
  if i == 0:
    color = next(colors_FEM)
    ax3.plot(eps_vals[1:], err_metad_long_FEM_TMD[1:, i,-1,-1], 
             # marker = 'o',
             color = color,
             label = "Mod. Gibbs Points")
    ax3.axvline(x = eps_vals[np.argmax(k_metad[1:,i,-1,-1])], linestyle = '--', color = color)
  else:
    color = next(colors_FEM)
    ax3.plot(eps_vals[1:], err_metad_long_FEM_TMD[1:, i,-1,-1], 
             # marker = 'o',
             color = color,
             label = "Mod. Gibbs points at delta =" + str(delta_vals[i]))
    ax3.axvline(x = eps_vals[np.argmax(k_metad[1:,i,-1,-1])], linestyle = '--', color = color)
ax3.legend(bbox_to_anchor=(0.40, 1.0))
ax3.set(ylim = (0.0,0.06), title = "Errors on modified\n Gibbs density", ylabel = "RMS Error", xlabel = "Kernel Bandwidth");

# %%
# plot dependence on delta net for gibbs data
colors_FEM = iter(plt.cm.jet(np.linspace(0,1,num_delta)))
fig, ax2 = plt.subplots(figsize = (8,8))
ax2.set(xscale = "log")
for i in range(4):
  if i == 0:
    color = next(colors_FEM)
    ax2.plot(eps_vals[1:], err_unif_FEM_TMD[1:, i,-1,-1], 
             # marker = 'o',
             color = color,
             label = "Uniform Points")
    ax2.axvline(x = eps_vals[np.argmax(k_unif[1:,i,-1,-1])], linestyle = '--', color = color)
  else:
    color = next(colors_FEM)
    ax2.plot(eps_vals[1:], err_unif_FEM_TMD[1:, i,-1,-1], 
             # marker = 'o',
             color = color,
             label = "Uniform points at delta =" + str(delta_vals[i]))
    ax2.axvline(x = eps_vals[np.argmax(k_unif[1:,i,-1,-1])], linestyle = '--', color = color)
ax2.legend(bbox_to_anchor=(0.40, 1.0))
ax2.set(ylim = (0.0,0.06), title = "Errors on Uniform Density", ylabel = "RMS Error", xlabel = "Kernel Bandwidth");

# %%
colors_FEM = iter(plt.cm.jet(np.linspace(0,1,3)))
fig, ax2 = plt.subplots(figsize = (8,8))
ax2.set(xscale = "log")
i=0
color = next(colors_FEM),
ax2.plot(eps_vals[1:], err_FEM_TMD[1:, i,-1,-1], 
         # marker = 'o',
         color = 'Blue',
         label = "Gibbs Points")
ax2.axvline(x = eps_vals[np.argmax(k_gibbs[1:,i,-1,-1])], linestyle = '--', color = 'Blue')
color = next(colors_FEM)
ax2.plot(eps_vals[1:], err_metad_long_FEM_TMD[1:, i,-1,-1], 
         # marker = 'o',
         color = 'Red',
         label = "Mod. Gibbs Points")
ax2.axvline(x = eps_vals[np.argmax(k_metad[1:,i,-1,-1])], linestyle = '--', color = 'Red')
color = next(colors_FEM)
ax2.plot(eps_vals[1:], err_unif_FEM_TMD[1:, i,-1,-1], 
         # marker = 'o',
         color = 'Black',
         label = "Uniform Points")
ax2.axvline(x = eps_vals[np.argmax(k_unif[1:,i,-1,-1])], linestyle = '--', color = 'Black')
ax2.legend(bbox_to_anchor=(0.40, 1.0))
ax2.set(ylim = (0.0,0.06), title = "Error analysis for different\n sampling densities", ylabel = "RMS Error", xlabel = "Kernel Bandwidth");
